# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\snarang1\Downloads\Medical_examination.csv', header=0)
df['bmi']= df['weight']/ ((df['height']/100)**2 )
print(df)
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio        bmi
# ...

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio        bmi
# ...

# %%
df['overweight']= 1

# %%
df.loc[df['bmi'] < 25, 'overweight'] = 0

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio        bmi  overweight
# ...

# %%
df['bmi'] < 25
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 69995    False
# 69996    False
# 69997    False
# 69998    False
# 69999     True
# Name: bmi, Length: 70000, dtype: bool

# %%
df['clean']=0

# %%
df.loc[ df['ap_lo'] <= df['ap_hi'], 'clean']= 1

# %%
df.loc[ df['height'] <= df['height'].quantile(0.025) , 'clean' ] = 1

# %%
df.loc[ df['height'] >= df['height'].quantile(0.975) , 'clean' ] = 1

# %%
df.loc[ df['weight'] >= df['weight'].quantile(0.975) , 'clean' ] = 1

# %%
df.loc[ df['weight'] <= df['weight'].quantile(0.025) , 'clean' ] = 1

# %%
df.loc[ df['clean'] == 0]
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 241      334  21932    2     157    60.0    160   1000            2     1
# 329      458  23407    1     176    63.0    160   1000            2     2
# 345      482  18704    1     154    81.0    140   1000            2     1
# 474      681  19099    1     156    65.0    120    150            2     1
# 559      805  20430    2     173   101.0    200   1000            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69771  99659  23330    1     167    81.0    160   1000            1     1
# 69872  99798  21808    1     152    56.0    160   1000            1     1
# 69878  99807  21239    2     168    95.0    160   1000            1     1
# 69885  99816  22417    2     166    78.0    170   1000            1     1
# 69967  99955  21416    2     168    63.0    140   1000            1     1
#
#        smoke  alco  active  cardio        bmi  overweight  clean
# ...

# %%
df=df.loc[ df ['clean']==0 ]

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 241      334  21932    2     157    60.0    160   1000            2     1
# 329      458  23407    1     176    63.0    160   1000            2     2
# 345      482  18704    1     154    81.0    140   1000            2     1
# 474      681  19099    1     156    65.0    120    150            2     1
# 559      805  20430    2     173   101.0    200   1000            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69771  99659  23330    1     167    81.0    160   1000            1     1
# 69872  99798  21808    1     152    56.0    160   1000            1     1
# 69878  99807  21239    2     168    95.0    160   1000            1     1
# 69885  99816  22417    2     166    78.0    170   1000            1     1
# 69967  99955  21416    2     168    63.0    140   1000            1     1
#
#        smoke  alco  active  cardio        bmi  overweight  clean
# ...
